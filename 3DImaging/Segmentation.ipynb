desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-092_ses-20100313_desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-099_ses-20100321_desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-100_ses-20100213_desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-101_ses-20100323_desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-103_ses-20100301_desc-brain_mask.nii.gz', 'C:\\Code\\ArteryImagingMalik\\data2\\train\\sub-104_ses-20100228_desc-brain_mask.nii. ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Code\ArteryImagingMalik\Segmentation.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Lets look at data we have
#       <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> dataset = Dataset(x_train_dir, y_train_dir, classes=['artery'])
# ----> <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> image, mask = dataset[100] # get some sample
#       <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> visualize(
#       <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     image=image,
#       <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>     artery_mask=mask[..., 0].squeeze(),
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     #mask=mask[..., 1].squeeze(),
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     #background_mask=mask[..., 2].squeeze(),
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> )
#
# c:\Code\ArteryImagingMalik\Segmentation.ipynb Cell 6 line 5
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=46'>47</a> def __getitem__(self, i):
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=47'>48</a>
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=48'>49</a>     # read data
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=49'>50</a>     image = cv2.imread(self.images_fps[i])
# ---> <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=50'>51</a>     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=51'>52</a>     mask = cv2.imread(self.masks_fps[i], 0)
#      <a href='vscode-notebook-cell:/c%3A/Code/ArteryImagingMalik/Segmentation.ipynb#W5sZmlsZQ%3D%3D?line=53'>54</a>     masks = [(mask == v) for v in self.class_values]
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=320, min_width=320, always_apply=True, border_mode=0),
        A.RandomCrop(height=320, width=320, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['artery'], augmentation=get_training_augmentation())

image, mask = dataset[50] # get some sample


visualize(
    image=image, 
    artery_mask=mask[..., 0].squeeze(),
)

# %%
import segmentation_models as sm

# segmentation_models could also use `tf.keras` if you do not have Keras installed
# or you could switch to other framework using `sm.set_framework('tf.keras')`
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'efficientnetb3'
BATCH_SIZE = 8
CLASSES = ['artery']
LR = 0.0001
EPOCHS = 40

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
dice_loss = sm.losses.DiceLoss(class_weights=np.array([1, 2, 0.5])) 
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 320, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 320, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
# train model
history = model.fit_generator(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    #validation_data=valid_dataloader, 
    #validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/40
# 37/37 [==============================] - 25s 669ms/step - loss: 0.6833 - iou_score: 0.8757 - f1-score: 0.9310
# Epoch 2/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.9572 - iou_score: 0.8870 - f1-score: 0.93925s - loss: 0.7233 - iou_ - ETA: 2s - loss: 0.8704 - iou_score:
# Epoch 3/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.8037 - iou_score: 0.8885 - f1-score: 0.94026s - loss: 0.2259 - iou_score: - ETA: 4s - loss: 0.7
# Epoch 4/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.8219 - iou_score: 0.8977 - f1-score: 0.94513s - loss: 0.7190
# Epoch 5/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.9038 - iou_score: 0.8834 - f1-score: 0.93674s - loss:
# Epoch 6/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7783 - iou_score: 0.8962 - f1-score: 0.94392s - loss: 0.7134 - iou_score: 0.8
# Epoch 7/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7340 - iou_score: 0.9032 - f1-score: 0.94852s - loss: 0.7717 - iou_score:
# Epoch 8/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.6687 - iou_score: 0.8768 - f1-score: 0.9332
# Epoch 9/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.6829 - iou_score: 0.8914 - f1-score: 0.9414
# Epoch 10/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.8294 - iou_score: 0.8933 - f1-score: 0.9422
# Epoch 11/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7843 - iou_score: 0.8984 - f1-score: 0.94565s
# Epoch 12/40
# 37/37 [==============================] - 8s 203ms/step - loss: 0.7174 - iou_score: 0.8990 - f1-score: 0.9461
# Epoch 13/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.9793 - iou_score: 0.8864 - f1-score: 0.9386
# Epoch 14/40
# 37/37 [==============================] - 7s 203ms/step - loss: 0.6907 - iou_score: 0.8975 - f1-score: 0.9450
# Epoch 15/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.5975 - iou_score: 0.9158 - f1-score: 0.95545s
# Epoch 16/40
# 37/37 [==============================] - 7s 203ms/step - loss: 0.9132 - iou_score: 0.8801 - f1-score: 0.9350
# Epoch 17/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.6940 - iou_score: 0.8879 - f1-score: 0.9354
# Epoch 18/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7102 - iou_score: 0.8981 - f1-score: 0.9454
# Epoch 19/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7948 - iou_score: 0.8831 - f1-score: 0.93675s -
# Epoch 20/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.8498 - iou_score: 0.8817 - f1-score: 0.9359
# Epoch 21/40
# 37/37 [==============================] - 7s 200ms/step - loss: 0.6751 - iou_score: 0.8940 - f1-score: 0.9431
# Epoch 22/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.7879 - iou_score: 0.8975 - f1-score: 0.9447
# Epoch 23/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.9551 - iou_score: 0.8886 - f1-score: 0.9397
# Epoch 24/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7797 - iou_score: 0.8881 - f1-score: 0.9394
# Epoch 25/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.7771 - iou_score: 0.8807 - f1-score: 0.9351
# Epoch 26/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7535 - iou_score: 0.8782 - f1-score: 0.93354s - loss: 0
# Epoch 27/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.8137 - iou_score: 0.8938 - f1-score: 0.9430
# Epoch 28/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7352 - iou_score: 0.8954 - f1-score: 0.9434
# Epoch 29/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.8581 - iou_score: 0.8864 - f1-score: 0.9390
# Epoch 30/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7531 - iou_score: 0.8859 - f1-score: 0.9386
# Epoch 31/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7570 - iou_score: 0.8850 - f1-score: 0.93785s -
# Epoch 32/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.7650 - iou_score: 0.8914 - f1-score: 0.9416
# Epoch 33/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.6703 - iou_score: 0.8800 - f1-score: 0.9339
# Epoch 34/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.9523 - iou_score: 0.8765 - f1-score: 0.9326
# Epoch 35/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.7350 - iou_score: 0.9000 - f1-score: 0.9466
# Epoch 36/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7689 - iou_score: 0.8925 - f1-score: 0.9423
# Epoch 37/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.8332 - iou_score: 0.8953 - f1-score: 0.9434
# Epoch 38/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.7842 - iou_score: 0.8858 - f1-score: 0.93804s - los
# Epoch 39/40
# 37/37 [==============================] - 7s 201ms/step - loss: 0.7899 - iou_score: 0.8908 - f1-score: 0.94143s - loss: 0.8222
# Epoch 40/40
# 37/37 [==============================] - 7s 202ms/step - loss: 0.6067 - iou_score: 0.9138 - f1-score: 0.9541

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-4532db4e0ba7> in <module>
#       3 plt.subplot(121)
#       4 plt.plot(history.history['iou_score'])
# ----> 5 plt.plot(history.history['val_iou_score'])
#       6 plt.title('Model iou_score')
#       7 plt.ylabel('iou_score')
#
# KeyError: 'val_iou_score'

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
#model.load_weights('best_model.h5')

# %%
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# Loss: -0.081427
# mean iou_score: 0.99701
# mean f1-score: 0.9985

# %%
n = 5
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask.squeeze(),
        pr_mask=pr_mask.squeeze(),
    )
